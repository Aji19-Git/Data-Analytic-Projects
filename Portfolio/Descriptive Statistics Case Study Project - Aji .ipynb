# %% [markdown]
# # Load and study the data
#
# Load the data and study its features such as:
# *   The number of employees
# *   The number of features
# *   The types of features

# %%
# Load "numpy" and "pandas" for manipulating numbers and dataframes
# Load "matplotlib.pyplot" and "seaborn" for data visualisation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the "Employee Dataset" file as a Pandas DataFrame
data = pd.read_csv('/content/Employee Dataset.csv')

# %%
# Take a brief look at the data
data.head()
# Out:
#    id groups  age  healthy_eating  active_lifestyle  salary
# 0   0      A   36               5                 5    2297
# 1   1      A   26               3                 5    1134
# 2   2      A   61               8                 1    4969
# 3   3      O   24               3                 6     902
# 4   4      O   39               6                 2    3574

# %%
# Get the dimensions of the dataframe
data.shape
# Out:
# (50, 6)

# %%
# Get the row names of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# Get the column names of the dataframe
data.columns
# Out:
# Index(['id', 'groups', 'age', 'healthy_eating', 'active_lifestyle', 'salary'], dtype='object')

# %%
# Look at basic information about the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                50 non-null     int64
#  1   Groups            50 non-null     object
#  2   Age               50 non-null     int64
#  3   Healthy_eating    50 non-null     int64
#  4   Active_lifestyle  50 non-null     int64
#  5   Salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %% [markdown]
# # Observations
#
# There are 50 rows and 6 columns in the data. Each row contains the employee specifics of a certain employee in the company
#
# The features in the data set are:
#
# 1. The id of the employees
#
# 2. Their respective groups and age
#
# 3. Their healthy_eating and active_lifestyle
#
# 4. Their salary

# %% [markdown]
# # Visualise the distributions of ratings and compensations
# We will now visualise the distributions of employee ratings and compensations
#
# We will create the following plots:
#
# 1. A scatter plot of employee age and employee salary, healthy_eating and active_lifestyle, health_eating and salary
#
# 2. A count plot of groups
#
# 3. A histogram of employee salary

# %%
# Create a scatter plot of the "Age" and "Employee Salary" features
plt.figure(figsize = (8,4))

sns.scatterplot(data = data, x = 'age', y = 'salary', color = 'green',
             edgecolor = 'linen', alpha = 0.5)


plt.title("Scatterplot of Employee Age v/s Employee Salary")
plt.xlabel('Employee Age')
plt.ylabel('Employee Salary')
plt.show()

# %% [markdown]
# # Observations:
#
# We observe that in general, there is a relationship between age and Salary of employee
#
# As age increases, the Salary also increases, though there are some outliers present as well

# %%
# Create a scatter plot of the "healthy_eating" and "active_lifestyle" features

plt.figure(figsize = (8,4))

sns.scatterplot(data = data ,x = 'healthy_eating', y = 'active_lifestyle', color = 'blue',
             edgecolor = 'linen', alpha = 0.7)

plt.title("Scatterplot of Healthy Eating v/s Active Lifestyle")
plt.xlabel('Healthy Eating')
plt.ylabel('Active Lifestyle')
plt.show()

# %% [markdown]
# # Observations:
#
# We observe that in general, there is a relationship between healthy_eating and active_lifestyle of employee.
#
# As healthy_eating increases, the active_lifestyle also increases.

# %%
# Create a scatter plot of the "healthy_eating" and "salary" features

plt.figure(figsize = (8,4))

sns.scatterplot(data = data, x = 'healthy_eating', y = 'salary', color = 'red',
             edgecolor = 'linen', alpha = 0.5)

plt.title("Scatterplot of Healthy Eating v/s Salary")
plt.xlabel('Healthy Eating')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Observations:
#
# We observe that in general, there is a relationship between healthy_eating and salary of employee.
#
# As healthy_eating increases, the salary also increases.

# %%
# Create a count plot of the "groups" feature

plt.figure(figsize = (8,4))

sns.countplot(data = data, x = 'groups', hue = 'groups', edgecolor = 'k', alpha = 0.5)

plt.title("Count Plot of Groups")
plt.xlabel('Groups')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Observation:
#
# We see that most employees either belong to Group A or Group O, with Group A having maximum frequency.

# %%
# Create a histogram of the "Salary" feature

plt.figure(figsize = (8,4))

sns.histplot(data = data,x = 'salary', color = 'Blue',
             edgecolor = 'linen', alpha = 0.5, bins = 10)

plt.title("Histogram of Salary")
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Observations:
#
# The salaries are not uniform, which is not necessarily a discrepancy.
#
# However, we observe that there are employees with salaries on either extremity of the histogram.
#
# Based on the histogram, we can see that the count of highest-earning employees is very low.

# %% [markdown]
# # Observations
# 1. Generally, as the employee's age increases, there is an increase in the employee's salary.
#
# 2. Generally, as the employee's healthy habits increase, there is an increase in the employee's salary as well.
#
# 3. However, the employee salary values are more spread out.
#
# 4. An employee of healthy_eating greater than 8 can be taken as 8 only.
#
# 5. An employee salary of less than 1000 can be considered a lower salary.

# %% [markdown]
# # Subset the data based on thresholds
#
# We will now subset the original data frame based on the following conditions:
#
# 1. Employees with health greater than 8
#
# 2. Employees with a Salary of less than 1000
#
# 3. Employees with health greater than 8 and with a salary less than 1000

# %%
# Employee healthy_eating is greater than 8

sub1 = data[data['healthy_eating'] > 8]
sub1
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %%
# salary less than 1000

sub2 = data[data['salary'] < 1000]
sub2
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 3    3      O   24               3                 6     902
# 15  15      B   26               3                 8     662
# 18  18      A   27               2                 6     779
# 26  26      A   62               9                 6     700
# 32  32      A   22               3                 8     662
# 35  35      O   27               2                 4     785
# 38  38     AB   26               3                 7     670
# 39  39      B   29               2                 6     779
# 43  43      O   23               4                10     556

# %%
# Employees with healthy_eating greater than 8 and with salary less than 1000

sub = data[(data['healthy_eating']>8) & (data['salary']<1000)]
sub
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %% [markdown]
# # Observations:
#
# The only employee seemingly facing a discrepancy in salary as compared to healthy_eating is an employee who has id = 26
#
# The employee with ID 26 has a salary of 700

# %% [markdown]
# # Final Conclusions
#
# From the given data, we can use simple visualizations to get a sense of how data are distributed.
#
# We can conduct preliminary analyses simply by subsetting data sets using well-thought-out thresholds and conditions.
